# %%
import pandas as pd

# %%
df=pd.read_csv("atm_cash_management_dataset.csv")

# %%
df.head()
# Out:
#      ATM_ID        Date Day_of_Week Time_of_Day  Total_Withdrawals  \
# 0  ATM_0041  2022-04-25      Monday     Morning              57450
# 1  ATM_0007  2023-11-24      Friday     Morning              72845
# 2  ATM_0014  2022-08-27    Saturday     Morning              42957
# 3  ATM_0029  2023-08-27      Sunday     Evening              43014
# 4  ATM_0028  2022-12-15    Thursday     Evening              36379
#
#    Total_Deposits Location_Type  Holiday_Flag  Special_Event_Flag  \
# 0            9308    Standalone             0                   0
# 1           17896   Supermarket             0                   0
# 2           12712   Supermarket             0                   0
# 3            1375          Mall             0                   0
# 4            2938   Bank Branch             0                   0
#
#    Previous_Day_Cash_Level Weather_Condition  Nearby_Competitor_ATMs  \
# 0                   112953             Rainy                       5
# ...

# %%
df.shape
# Out:
# (5658, 13)

# %%
df.columns
# Out:
# Index(['ATM_ID', 'Date', 'Day_of_Week', 'Time_of_Day', 'Total_Withdrawals',
#        'Total_Deposits', 'Location_Type', 'Holiday_Flag', 'Special_Event_Flag',
#        'Previous_Day_Cash_Level', 'Weather_Condition',
#        'Nearby_Competitor_ATMs', 'Cash_Demand_Next_Day'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5658 entries, 0 to 5657
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ATM_ID                   5658 non-null   object
#  1   Date                     5658 non-null   object
#  2   Day_of_Week              5658 non-null   object
#  3   Time_of_Day              5658 non-null   object
#  4   Total_Withdrawals        5658 non-null   int64
#  5   Total_Deposits           5658 non-null   int64
#  6   Location_Type            5658 non-null   object
#  7   Holiday_Flag             5658 non-null   int64
#  8   Special_Event_Flag       5658 non-null   int64
#  9   Previous_Day_Cash_Level  5658 non-null   int64
#  10  Weather_Condition        5658 non-null   object
#  11  Nearby_Competitor_ATMs   5658 non-null   int64
#  12  Cash_Demand_Next_Day     5658 non-null   int64
# dtypes: int64(7), object(6)
# memory usage: 574.8+ KB

# %%
df.dtypes
# Out:
# ATM_ID                     object
# Date                       object
# Day_of_Week                object
# Time_of_Day                object
# Total_Withdrawals           int64
# Total_Deposits              int64
# Location_Type              object
# Holiday_Flag                int64
# Special_Event_Flag          int64
# Previous_Day_Cash_Level     int64
# Weather_Condition          object
# Nearby_Competitor_ATMs      int64
# Cash_Demand_Next_Day        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['ATM_ID', 'Date', 'Day_of_Week', 'Time_of_Day', 'Total_Withdrawals',
#        'Total_Deposits', 'Location_Type', 'Holiday_Flag', 'Special_Event_Flag',
#        'Previous_Day_Cash_Level', 'Weather_Condition',
#        'Nearby_Competitor_ATMs', 'Cash_Demand_Next_Day'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ATM_ID                     0
# Date                       0
# Day_of_Week                0
# Time_of_Day                0
# Total_Withdrawals          0
# Total_Deposits             0
# Location_Type              0
# Holiday_Flag               0
# Special_Event_Flag         0
# Previous_Day_Cash_Level    0
# Weather_Condition          0
# Nearby_Competitor_ATMs     0
# Cash_Demand_Next_Day       0
# dtype: int64

# %%
df["Cash_Demand_Next_Day"].describe()
# Out:
# count      5658.000000
# mean      43085.207494
# std       16797.100086
# min           0.000000
# 25%       31558.750000
# 50%       42589.500000
# 75%       53831.000000
# max      114724.000000
# Name: Cash_Demand_Next_Day, dtype: float64

# %%
df["Cash_Demand_Next_Day"].hist()
# Out:
# <Axes: >

# %%
df["Cash_Demand_Next_Day"].plot(kind="box")
# Out:
# <Axes: >

# %%
df.groupby("Location_Type")["Cash_Demand_Next_Day"].mean()
# Out:
# Location_Type
# Bank Branch    43617.276316
# Gas Station    43112.919580
# Mall           42423.671208
# Standalone     42777.797723
# Supermarket    43475.262599
# Name: Cash_Demand_Next_Day, dtype: float64

# %%
df.groupby("Day_of_Week")["Cash_Demand_Next_Day"].mean().sort_values(ascending=False)
# Out:
# Day_of_Week
# Sunday       43676.686732
# Tuesday      43328.164366
# Friday       43175.278729
# Wednesday    43133.503896
# Thursday     42839.079462
# Saturday     42809.879012
# Monday       42650.046931
# Name: Cash_Demand_Next_Day, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                          Total_Withdrawals  Total_Deposits  Holiday_Flag  \
# Total_Withdrawals                 1.000000       -0.000420     -0.028994
# Total_Deposits                   -0.000420        1.000000     -0.000877
# Holiday_Flag                     -0.028994       -0.000877      1.000000
# Special_Event_Flag               -0.004441        0.025669     -0.008399
# Previous_Day_Cash_Level          -0.009252       -0.009107      0.006642
# Nearby_Competitor_ATMs           -0.012022        0.006298     -0.023580
# Cash_Demand_Next_Day              0.895053       -0.213557      0.019698
#
#                          Special_Event_Flag  Previous_Day_Cash_Level  \
# Total_Withdrawals                 -0.004441                -0.009252
# Total_Deposits                     0.025669                -0.009107
# Holiday_Flag                      -0.008399                 0.006642
# Special_Event_Flag                 1.000000                 0.004580
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5658 entries, 0 to 5657
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ATM_ID                   5658 non-null   object
#  1   Date                     5658 non-null   object
#  2   Day_of_Week              5658 non-null   object
#  3   Time_of_Day              5658 non-null   object
#  4   Total_Withdrawals        5658 non-null   int64
#  5   Total_Deposits           5658 non-null   int64
#  6   Location_Type            5658 non-null   object
#  7   Holiday_Flag             5658 non-null   int64
#  8   Special_Event_Flag       5658 non-null   int64
#  9   Previous_Day_Cash_Level  5658 non-null   int64
#  10  Weather_Condition        5658 non-null   object
#  11  Nearby_Competitor_ATMs   5658 non-null   int64
#  12  Cash_Demand_Next_Day     5658 non-null   int64
# dtypes: int64(7), object(6)
# memory usage: 574.8+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5658 entries, 0 to 5657
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ATM_ID                   5658 non-null   object
#  1   Date                     5658 non-null   datetime64[ns]
#  2   Day_of_Week              5658 non-null   object
#  3   Time_of_Day              5658 non-null   object
#  4   Total_Withdrawals        5658 non-null   int64
#  5   Total_Deposits           5658 non-null   int64
#  6   Location_Type            5658 non-null   object
#  7   Holiday_Flag             5658 non-null   int64
#  8   Special_Event_Flag       5658 non-null   int64
#  9   Previous_Day_Cash_Level  5658 non-null   int64
#  10  Weather_Condition        5658 non-null   object
#  11  Nearby_Competitor_ATMs   5658 non-null   int64
#  12  Cash_Demand_Next_Day     5658 non-null   int64
#  13  Month                    5658 non-null   int32
# ...

# %%
df["Month"]=df["Date"].dt.month

# %%
df[["Date" , "Month"]].head()
# Out:
#         Date  Month
# 0 2022-04-25      4
# 1 2023-11-24     11
# 2 2022-08-27      8
# 3 2023-08-27      8
# 4 2022-12-15     12

# %%
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day
df["Quarter"] = df["Date"].dt.quarter

# %%
df[["Year" , "Month", "Day" , "Quarter" ]].head()
# Out:
#    Year  Month  Day  Quarter
# 0  2022      4   25        2
# 1  2023     11   24        4
# 2  2022      8   27        3
# 3  2023      8   27        3
# 4  2022     12   15        4

# %%
df["Year"].value_counts()
# Out:
# Year
# 2023    2865
# 2022    2783
# 2024      10
# Name: count, dtype: int64

# %%
df["Day_of_Week"].unique()
df["Time_of_Day"].unique()
#df["Location_Type"].unique()
#df["Weather_Condition"].unique()
# Out:
# array(['Morning', 'Evening', 'Afternoon', 'Night'], dtype=object)

# %%
df["Location_Type"].nunique()
# Out:
# 5

# %%
pd.get_dummies(df["Time_of_Day"])
# Out:
#       Afternoon  Evening  Morning  Night
# 0         False    False     True  False
# 1         False    False     True  False
# 2         False    False     True  False
# 3         False     True    False  False
# 4         False     True    False  False
# ...         ...      ...      ...    ...
# 5653      False    False    False   True
# 5654       True    False    False  False
# 5655      False     True    False  False
# 5656      False    False    False   True
# 5657      False     True    False  False
#
# [5658 rows x 4 columns]

# %%
pd.get_dummies(df["Time_of_Day"])
# Out:
#       Afternoon  Evening  Morning  Night
# 0         False    False     True  False
# 1         False    False     True  False
# 2         False    False     True  False
# 3         False     True    False  False
# 4         False     True    False  False
# ...         ...      ...      ...    ...
# 5653      False    False    False   True
# 5654       True    False    False  False
# 5655      False     True    False  False
# 5656      False    False    False   True
# 5657      False     True    False  False
#
# [5658 rows x 4 columns]

# %%
categorical_columns = [
    "Day_of_Week",
    "Time_of_Day",
    "Location_Type",
    "Weather_Condition"
]

# %%
df_encoded = pd.get_dummies(
    df,
    columns=categorical_columns,
    drop_first=True
)

# %%
df_encoded
# Out:
#         ATM_ID       Date  Total_Withdrawals  Total_Deposits  Holiday_Flag  \
# 0     ATM_0041 2022-04-25              57450            9308             0
# 1     ATM_0007 2023-11-24              72845           17896             0
# 2     ATM_0014 2022-08-27              42957           12712             0
# 3     ATM_0029 2023-08-27              43014            1375             0
# 4     ATM_0028 2022-12-15              36379            2938             0
# ...        ...        ...                ...             ...           ...
# 5653  ATM_0029 2022-07-02              32027            3097             0
# 5654  ATM_0050 2023-12-08              60120            4948             0
# 5655  ATM_0036 2022-10-04              32551           10819             0
# 5656  ATM_0010 2022-04-19              52965           13372             0
# 5657  ATM_0039 2022-07-26              61754           11348             0
#
# ...

# %%
df_encoded.head()
# Out:
#      ATM_ID       Date  Total_Withdrawals  Total_Deposits  Holiday_Flag  \
# 0  ATM_0041 2022-04-25              57450            9308             0
# 1  ATM_0007 2023-11-24              72845           17896             0
# 2  ATM_0014 2022-08-27              42957           12712             0
# 3  ATM_0029 2023-08-27              43014            1375             0
# 4  ATM_0028 2022-12-15              36379            2938             0
#
#    Special_Event_Flag  Previous_Day_Cash_Level  Nearby_Competitor_ATMs  \
# 0                   0                   112953                       5
# 1                   0                   115348                       0
# 2                   0                    90731                       1
# 3                   0                    88754                       5
# 4                   0                   129312                       0
#
#    Cash_Demand_Next_Day  Month  ...  Time_of_Day_Evening  Time_of_Day_Morning  \
# ...

# %%
df_encoded.shape
# Out:
# (5658, 29)

# %%
df.shape
# Out:
# (5658, 17)

# %%
df["Year"].value_counts()
# Out:
# Year
# 2023    2865
# 2022    2783
# 2024      10
# Name: count, dtype: int64
